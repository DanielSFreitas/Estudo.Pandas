# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielSFreitas/teste/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Atividade/tournaments.csv')
df.head(30)
# Out:
# <ipython-input-2-1d9925a14fbc>:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/MyDrive/Atividade/tournaments.csv')
#    id_card             name_card  amount_card price_card energy_type_card  \
# 0   SSP272              Archeops            4        0.7        Colorless
# 1   SIT138               Lugia V            3        6.2        Colorless
# 2   SIT139           Lugia VSTAR            3       8.71        Colorless
# 3   LOR143               Snorlax            3       0.93        Colorless
# 4   SSP250            Lumineon V            2        1.9            Water
# 5   LOR118             Drapion V            1       0.95         Darkness
# 6   SVP053                Mew ex            1       9.25          Psychic
# 7   PAL071                Luxray            1       0.14        Lightning
# 8   ASR134             Wyrdeer V            1       0.84        Colorless
# ...

# %%
# Criando dataframe 'pessoas' a partir do dicionario
pessoas = pd.DataFrame({
    'Nome': ['Ana', 'Carlos'],
    'Idade': [25, 30]
})

# exibe dataframe 'pessoas'
pessoas
# Out:
#      Nome  Idade
# 0     Ana     25
# 1  Carlos     30

# %%
# Cria dataframe 'pessoas_2' partir de lista de listas
pessoas_2 = pd.DataFrame([
    ['Ana', 25],
    ['Carlos', 30]
])

#exibe dataframe 'pessoas_2'
pessoas_2
# Out:
#         0   1
# 0     Ana  25
# 1  Carlos  30

# %%
df.tail()
# Out:
#         id_card         name_card  amount_card price_card energy_type_card  \
# 114286  GRI130a  Rescue Stretcher            2       0.72             None
# 114287   GRI119        Aqua Patch            2       0.27             None
# 114288   FLF092           Pal Pad            1       0.68             None
# 114289   GRI121       Choice Band            2        0.2             None
# 114290   GRI120     Brooklet Hill            2       0.32             None
#
#        type_card combo_type_id   combo_type_name  id_player  name_player  ...  \
# 114286   Trainer            47  Zoroark Greninja       1900  Jin Woo Lee  ...
# 114287   Trainer            47  Zoroark Greninja       1900  Jin Woo Lee  ...
# 114288   Trainer            47  Zoroark Greninja       1900  Jin Woo Lee  ...
# 114289   Trainer            47  Zoroark Greninja       1900  Jin Woo Lee  ...
# 114290   Trainer            47  Zoroark Greninja       1900  Jin Woo Lee  ...
#
# ...

# %%
df.shape
# Out:
# (114291, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114291 entries, 0 to 114290
# Data columns (total 26 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   id_card                       114291 non-null  object
#  1   name_card                     114291 non-null  object
#  2   amount_card                   114291 non-null  int64
#  3   price_card                    114291 non-null  object
#  4   energy_type_card              114291 non-null  object
#  5   type_card                     114291 non-null  object
#  6   combo_type_id                 114291 non-null  object
#  7   combo_type_name               114291 non-null  object
#  8   id_player                     114291 non-null  int64
#  9   name_player                   114291 non-null  object
#  10  country_player                114291 non-null  object
#  11  all_time_score                114291 non-null  int64
# ...

# %%
print(f"Temos {df.shape[0]} linhas e {df.shape[1]} colunas")
# Out:
# Temos 114291 linhas e 26 colunas

# %%
#usando colchetes
print (df['name_card'])
# Out:
# 0                 Archeops
# 1                  Lugia V
# 2              Lugia VSTAR
# 3                  Snorlax
# 4               Lumineon V
#                 ...
# 114286    Rescue Stretcher
# 114287          Aqua Patch
# 114288             Pal Pad
# 114289         Choice Band
# 114290       Brooklet Hill
# Name: name_card, Length: 114291, dtype: object

# %%
#usando notação de ponto
print(df.name_card)
# Out:
# 0                 Archeops
# 1                  Lugia V
# 2              Lugia VSTAR
# 3                  Snorlax
# 4               Lumineon V
#                 ...
# 114286    Rescue Stretcher
# 114287          Aqua Patch
# 114288             Pal Pad
# 114289         Choice Band
# 114290       Brooklet Hill
# Name: name_card, Length: 114291, dtype: object

# %%
#exibe da linha 3 a 8
df['name_card'][3:8]
# Out:
# 3       Snorlax
# 4    Lumineon V
# 5     Drapion V
# 6        Mew ex
# 7        Luxray
# Name: name_card, dtype: object

# %%
#exibe linha 4
df['name_card'][4]
# Out:
# 'Lumineon V'

# %%
df[['name_card', 'price_card', 'type_card']]
# Out:
#                name_card price_card type_card
# 0               Archeops        0.7   Pokémon
# 1                Lugia V        6.2   Pokémon
# 2            Lugia VSTAR       8.71   Pokémon
# 3                Snorlax       0.93   Pokémon
# 4             Lumineon V        1.9   Pokémon
# ...                  ...        ...       ...
# 114286  Rescue Stretcher       0.72   Trainer
# 114287        Aqua Patch       0.27   Trainer
# 114288           Pal Pad       0.68   Trainer
# 114289       Choice Band        0.2   Trainer
# 114290     Brooklet Hill       0.32   Trainer
#
# [114291 rows x 3 columns]

# %%
df.loc[0]
# Out:
# id_card                                         SSP272
# name_card                                     Archeops
# amount_card                                          4
# price_card                                         0.7
# energy_type_card                             Colorless
# type_card                                      Pokémon
# combo_type_id                                      247
# combo_type_name                         Lugia Archeops
# id_player                                         5101
# name_player                           Alexander Flatos
# country_player                           United States
# all_time_score                                      27
# ranking_player_tournament                            1
# id_tournament                                      387
# category_tournament                           regional
# name_tournament                 Regional Sacramento CA
# region_tournament                                  NaN
# ...

# %%
df.loc[[0,1]]
# Out:
#   id_card name_card  amount_card price_card energy_type_card type_card  \
# 0  SSP272  Archeops            4        0.7        Colorless   Pokémon
# 1  SIT138   Lugia V            3        6.2        Colorless   Pokémon
#
#   combo_type_id combo_type_name  id_player       name_player  ...  \
# 0           247  Lugia Archeops       5101  Alexander Flatos  ...
# 1           247  Lugia Archeops       5101  Alexander Flatos  ...
#
#   region_tournament  country_tournament  year_tournament  month_tournament  \
# 0               NaN       United States             2023                10
# 1               NaN       United States             2023                10
#
#   day_tournament valid_rotation_at_tournament  rotation_name year_begin  \
# 0             14                      BST-OBF  standard_2023       2023
# 1             14                      BST-OBF  standard_2023       2023
#
#    month_begin  day_begin
# 0            4         14
# 1            4         14
#
# ...

# %%
df.loc[0, 'name_card']
# Out:
# 'Archeops'

# %%
df.loc[df['amount_card'] > 3 ]
# Out:
#         id_card             name_card  amount_card price_card  \
# 0        SSP272              Archeops            4        0.7
# 9        SSP152  Professor's Research            4        2.2
# 13       DEX102            Ultra Ball            4        0.5
# 14       SIT153       Capturing Aroma            4       0.18
# 18       SSP204              Arceus V            4       5.65
# ...         ...                   ...          ...        ...
# 114273   FLI022               Froakie            4        0.2
# 114274   FLI023             Frogadier            4       0.33
# 114278  UPR119a               Cynthia            4      25.18
# 114283   DEX102            Ultra Ball            4        0.5
# 114284   EPO093            Great Ball            4       0.26
#
#        energy_type_card type_card combo_type_id   combo_type_name  id_player  \
# 0             Colorless   Pokémon           247    Lugia Archeops       5101
# ...

# %%
df.iloc[0]
# Out:
# id_card                                         SSP272
# name_card                                     Archeops
# amount_card                                          4
# price_card                                         0.7
# energy_type_card                             Colorless
# type_card                                      Pokémon
# combo_type_id                                      247
# combo_type_name                         Lugia Archeops
# id_player                                         5101
# name_player                           Alexander Flatos
# country_player                           United States
# all_time_score                                      27
# ranking_player_tournament                            1
# id_tournament                                      387
# category_tournament                           regional
# name_tournament                 Regional Sacramento CA
# region_tournament                                  NaN
# ...

# %%
df.iloc[[10,3]]
# Out:
#    id_card name_card  amount_card price_card energy_type_card type_card  \
# 10  PAL185      Iono            3       2.68             None   Trainer
# 3   LOR143   Snorlax            3       0.93        Colorless   Pokémon
#
#    combo_type_id combo_type_name  id_player       name_player  ...  \
# 10           247  Lugia Archeops       5101  Alexander Flatos  ...
# 3            247  Lugia Archeops       5101  Alexander Flatos  ...
#
#    region_tournament  country_tournament  year_tournament  month_tournament  \
# 10               NaN       United States             2023                10
# 3                NaN       United States             2023                10
#
#    day_tournament valid_rotation_at_tournament  rotation_name year_begin  \
# 10             14                      BST-OBF  standard_2023       2023
# 3              14                      BST-OBF  standard_2023       2023
#
#     month_begin  day_begin
# 10            4         14
# 3             4         14
#
# ...

# %%
print (df.iloc[10,4])
# Out:
# None

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114291 entries, 0 to 114290
# Data columns (total 26 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   id_card                       114291 non-null  object
#  1   name_card                     114291 non-null  object
#  2   amount_card                   114291 non-null  int64
#  3   price_card                    114291 non-null  object
#  4   energy_type_card              114291 non-null  object
#  5   type_card                     114291 non-null  object
#  6   combo_type_id                 114291 non-null  object
#  7   combo_type_name               114291 non-null  object
#  8   id_player                     114291 non-null  int64
#  9   name_player                   114291 non-null  object
#  10  country_player                114291 non-null  object
#  11  all_time_score                114291 non-null  int64
# ...

# %%
#Adicionando colunas
df['Ano_Analise'] = 2023

#Adicionando coluna com condição
import numpy as np

df['Muito_forte'] = np.where(
    df['ranking_player_tournament'] <3,
    'Sim',
    'Não'
)
df.head()
# Out:
#   id_card    name_card  amount_card price_card energy_type_card type_card  \
# 0  SSP272     Archeops            4        0.7        Colorless   Pokémon
# 1  SIT138      Lugia V            3        6.2        Colorless   Pokémon
# 2  SIT139  Lugia VSTAR            3       8.71        Colorless   Pokémon
# 3  LOR143      Snorlax            3       0.93        Colorless   Pokémon
# 4  SSP250   Lumineon V            2        1.9            Water   Pokémon
#
#   combo_type_id combo_type_name  id_player       name_player  ...  \
# 0           247  Lugia Archeops       5101  Alexander Flatos  ...
# 1           247  Lugia Archeops       5101  Alexander Flatos  ...
# 2           247  Lugia Archeops       5101  Alexander Flatos  ...
# 3           247  Lugia Archeops       5101  Alexander Flatos  ...
# 4           247  Lugia Archeops       5101  Alexander Flatos  ...
#
#   year_tournament  month_tournament  day_tournament  \
# 0            2023                10              14
# ...

# %%
df.drop(columns='Ano_Analise')
# Out:
#         id_card         name_card  amount_card price_card energy_type_card  \
# 0        SSP272          Archeops            4        0.7        Colorless
# 1        SIT138           Lugia V            3        6.2        Colorless
# 2        SIT139       Lugia VSTAR            3       8.71        Colorless
# 3        LOR143           Snorlax            3       0.93        Colorless
# 4        SSP250        Lumineon V            2        1.9            Water
# ...         ...               ...          ...        ...              ...
# 114286  GRI130a  Rescue Stretcher            2       0.72             None
# 114287   GRI119        Aqua Patch            2       0.27             None
# 114288   FLF092           Pal Pad            1       0.68             None
# 114289   GRI121       Choice Band            2        0.2             None
# 114290   GRI120     Brooklet Hill            2       0.32             None
#
# ...

# %%
df.drop(columns="Ano_Analise", inplace=True)
df.head()
# Out:
#   id_card    name_card  amount_card price_card energy_type_card type_card  \
# 0  SSP272     Archeops            4        0.7        Colorless   Pokémon
# 1  SIT138      Lugia V            3        6.2        Colorless   Pokémon
# 2  SIT139  Lugia VSTAR            3       8.71        Colorless   Pokémon
# 3  LOR143      Snorlax            3       0.93        Colorless   Pokémon
# 4  SSP250   Lumineon V            2        1.9            Water   Pokémon
#
#   combo_type_id combo_type_name  id_player       name_player  ...  \
# 0           247  Lugia Archeops       5101  Alexander Flatos  ...
# 1           247  Lugia Archeops       5101  Alexander Flatos  ...
# 2           247  Lugia Archeops       5101  Alexander Flatos  ...
# 3           247  Lugia Archeops       5101  Alexander Flatos  ...
# 4           247  Lugia Archeops       5101  Alexander Flatos  ...
#
#   country_tournament  year_tournament  month_tournament  day_tournament  \
# ...

# %%
df['Muito_forte'] = df['Muito_forte'].map({'Sim':1,'Não':0})

df["Ano_Analise"] = 2023

df.head()
# Out:
#   id_card    name_card  amount_card price_card energy_type_card type_card  \
# 0  SSP272     Archeops            4        0.7        Colorless   Pokémon
# 1  SIT138      Lugia V            3        6.2        Colorless   Pokémon
# 2  SIT139  Lugia VSTAR            3       8.71        Colorless   Pokémon
# 3  LOR143      Snorlax            3       0.93        Colorless   Pokémon
# 4  SSP250   Lumineon V            2        1.9            Water   Pokémon
#
#   combo_type_id combo_type_name  id_player       name_player  ...  \
# 0           247  Lugia Archeops       5101  Alexander Flatos  ...
# 1           247  Lugia Archeops       5101  Alexander Flatos  ...
# 2           247  Lugia Archeops       5101  Alexander Flatos  ...
# 3           247  Lugia Archeops       5101  Alexander Flatos  ...
# 4           247  Lugia Archeops       5101  Alexander Flatos  ...
#
#   year_tournament  month_tournament  day_tournament  \
# 0            2023                10              14
# ...

# %%
df.describe()
# Out:
#          amount_card      id_player  all_time_score  \
# count  114291.000000  114291.000000   114291.000000
# mean        2.150869    2432.756341      100.721177
# std         1.172458    1689.635106      158.626738
# min         1.000000       1.000000        1.000000
# 25%         1.000000     712.000000       12.000000
# 50%         2.000000    2435.000000       34.000000
# 75%         3.000000    4055.000000      108.000000
# max         4.000000    5162.000000      943.000000
#
#        ranking_player_tournament  id_tournament  year_tournament  \
# count              114291.000000  114291.000000    114291.000000
# mean                   47.290469     300.991942      2021.575461
# std                    42.015853      89.110764         2.330584
# min                     1.000000       4.000000      2011.000000
# 25%                    13.000000     289.000000      2020.000000
# 50%                    35.000000     329.000000      2023.000000
# ...

# %%
df['energy_type_card'].value_counts()
# Out:
# None                 71844
# Psychic               8673
# Water                 8163
# Colorless             7308
# Darkness              3805
# GX                    3140
# Lightning             2948
# Fighting              1947
# Dragon                1606
# Fire                  1457
# Metal                 1432
# EX                     927
# Grass                  691
# Fairy                  145
# UNION                  112
# Pao ex                  77
# Oh                       5
# Lightning Grass          2
# Chien ex                 2
# Colorless Psychic        2
# Water Fire               2
# Z                        2
# Lu ex                    1
# Name: energy_type_card, dtype: int64

# %%
df['energy_type_card'].value_counts(normalize=True)
# Out:
# None                 0.628606
# Psychic              0.075885
# Water                0.071423
# Colorless            0.063942
# Darkness             0.033292
# GX                   0.027474
# Lightning            0.025794
# Fighting             0.017035
# Dragon               0.014052
# Fire                 0.012748
# Metal                0.012529
# EX                   0.008111
# Grass                0.006046
# Fairy                0.001269
# UNION                0.000980
# Pao ex               0.000674
# Oh                   0.000044
# Lightning Grass      0.000017
# Chien ex             0.000017
# Colorless Psychic    0.000017
# Water Fire           0.000017
# Z                    0.000017
# Lu ex                0.000009
# Name: energy_type_card, dtype: float64

# %%
df.groupby("price_card")["Muito_forte"].mean()
# Out:
# price_card
# 0.02    0.090909
# 0.03    0.015748
# 0.04    0.026946
# 0.05    0.031207
# 0.06    0.030322
#           ...
# 9.43    0.000000
# 9.72    0.142857
# 9.75    0.000000
# 9.96    0.333333
# None    0.041463
# Name: Muito_forte, Length: 559, dtype: float64

# %%
print(df.category_tournament)
# Out:
# 0         regional
# 1         regional
# 2         regional
# 3         regional
# 4         regional
#             ...
# 114286      others
# 114287      others
# 114288      others
# 114289      others
# 114290      others
# Name: category_tournament, Length: 114291, dtype: object

# %%
df.groupby("price_card")[["ranking_player_tournament","Muito_forte"]].mean()
# Out:
#             ranking_player_tournament  Muito_forte
# price_card
# 0.02                        42.818182     0.090909
# 0.03                        49.724409     0.015748
# 0.04                        50.571856     0.026946
# 0.05                        48.350902     0.031207
# 0.06                        55.360767     0.030322
# ...                               ...          ...
# 9.43                        20.500000     0.000000
# 9.72                        24.857143     0.142857
# 9.75                        52.153846     0.000000
# 9.96                         3.666667     0.333333
# None                        52.713821     0.041463
#
# [559 rows x 2 columns]

# %%
df.groupby(["price_card","ranking_player_tournament"])["amount_card"].std()
# Out:
# price_card  ranking_player_tournament
# 0.02        2                           NaN
#             6                           NaN
#             14                          NaN
#             17                          NaN
#             18                          NaN
#                                          ..
# None        189                         NaN
#             190                         NaN
#             191                         NaN
#             192                         NaN
#             193                         NaN
# Name: amount_card, Length: 27593, dtype: float64
